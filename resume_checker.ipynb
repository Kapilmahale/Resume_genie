# %%
# import os
# from dotenv import load_dotenv
# load_dotenv()

# os.environ["GROK_API_KEY"]=os.getenv("GROK_API_KEY")

# %%
# from langchain_xai import ChatXAI

# chat =ChatXAI(
#     model="grok-4",
#     api_key=XAI_API_KEY


# )

# result=chat.invoke("what is mcp server")

# %%
# %pip install langchain

# %%
# %pip install langchain-google-genai

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model("google_genai:gemini-2.5-flash-lite")
model
# Out:
# ChatGoogleGenerativeAI(metadata={'lc_versions': {'langchain-core': '1.4.8', 'langchain': '1.3.11', 'langchain-google-genai': '4.2.6'}}, output_version=None, profile={'name': 'Gemini 2.5 Flash-Lite', 'release_date': '2025-06-17', 'last_updated': '2025-06-17', 'open_weights': False, 'max_input_tokens': 1048576, 'max_output_tokens': 65536, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': True, 'pdf_inputs': True, 'video_inputs': True, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'image_tool_message': True, 'tool_choice': True}, google_api_key=SecretStr('**********'), location=None, model='gemini-2.5-flash-lite', client=<google.genai.client.Client object at 0x000002478CE3A3C0>, default_metadata=(), model_kwargs={})

# %%
model.invoke("what is mcp server")

# %%
for chunk in model.stream("what is kafka"):
    print(chunk.text,end="",flush=True)
# Out:
# Kafka is a **distributed event streaming platform**. This is its core definition, and it's important
# ---------------------------------------------------------------------------
# ServerError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 for chunk in model.stream("what is kafka"):
#       2     print(chunk.text,end="",flush=True)
#
# File c:\NON_CORE\Projects_26\Resume_genie\.venv_02\Lib\site-packages\langchain_core\language_models\chat_models.py:778, in BaseChatModel.stream(self, input, config, stop, **kwargs)
#     776 index = -1
#     777 index_type = ""
# --> 778 for chunk in self._stream(input_messages, stop=stop, **kwargs):
#     779     if chunk.message.id is None:
#     780         chunk.message.id = run_id
#
# File c:\NON_CORE\Projects_26\Resume_genie\.venv_02\Lib\site-packages\langchain_google_genai\chat_models.py:3395, in ChatGoogleGenerativeAI._stream(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3393 index = -1
#    3394 index_type = ""
# -> 3395 for chunk in response:
#    3396     if chunk:
#    3397         _chat_result = _response_to_result(
#    3398             chunk, stream=True, prev_usage=prev_usage_metadata
#    3399         )
#
# File c:\NON_CORE\Projects_26\Resume_genie\.venv_02\Lib\site-packages\google\genai\models.py:6709, in Models.generate_content_stream(self, model, contents, config)
#    6701 response = self._generate_content_stream(
#    6702     model=model, contents=contents, config=parsed_config_to_call
#    6703 )
#    6705 if i == 1:
#    6706   # First request gets a function call.
#    6707   # Then get function response parts.
#    6708   # Yield chunks only if there's no function response parts.
# -> 6709   for chunk in response:
#    6710     if not function_map:
#    6711       contents = _extra_utils.append_chunk_contents(contents, chunk)  # type: ignore[assignment]
#
# File c:\NON_CORE\Projects_26\Resume_genie\.venv_02\Lib\site-packages\google\genai\models.py:5062, in Models._generate_content_stream(self, model, contents, config)
#    5054 if config is not None and getattr(
#    5055     config, 'should_return_http_response', None
#    5056 ):
#    5057   raise ValueError(
#    5058       'Accessing the raw HTTP response is not supported in streaming'
#    5059       ' methods.'
#    5060   )
# -> 5062 for response in self._api_client.request_streamed(
#    5063     'post', path, request_dict, http_options
#    5064 ):
#    5066   response_dict = {} if not response.body else json.loads(response.body)
#    5068   if self._api_client.vertexai:
#
# File c:\NON_CORE\Projects_26\Resume_genie\.venv_02\Lib\site-packages\google\genai\_api_client.py:1641, in BaseApiClient.request_streamed(self, http_method, path, request_dict, http_options)
#    1639   if chunk_dump.startswith('{"error":'):
#    1640     chunk_json = json.loads(chunk_dump)
# -> 1641     errors.APIError.raise_error(
#    1642         chunk_json.get('error', {}).get('code'),
#    1643         chunk_json,
#    1644         session_response,
#    1645     )
#    1646 except json.decoder.JSONDecodeError:
#    1647   logger.debug(
#    1648       'Failed to decode chunk that contains an error: %s' % chunk_dump
#    1649   )
#
# File c:\NON_CORE\Projects_26\Resume_genie\.venv_02\Lib\site-packages\google\genai\errors.py:186, in APIError.raise_error(cls, status_code, response_json, response)
#     184   raise ClientError(status_code, response_json, response)
#     185 elif 500 <= status_code < 600:
# --> 186   raise ServerError(status_code, response_json, response)
#     187 else:
#     188   raise cls(status_code, response_json, response)
#
# ServerError: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}

# %% [markdown]
# ### PDF Based RAG Bot

# %%
from langchain_community.document_loaders import PyPDFLoader
loader=PyPDFLoader("Resume_KapilMahale.pdf")
documents=loader.load()

context="\n\n".join(doc.page_content for doc in documents)
# Out:
# C:\Users\Kapil\AppData\Local\Temp\ipykernel_26772\3137602578.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader

# %%
from langchain_core.prompts import PromptTemplate

prompt=PromptTemplate(
    input_variables=["context","question"],
    template="""

    You are an expert Technical Recruiter, ATS (Applicant Tracking System), and Career Coach.
    Your task is to thoroughly analyze the resume and generate a structured evaluation.

    1. Give an Overall Resume Score out of 100.
    2. Provide Overall Verdict:
    Choose exactly one:
    - Excellent
    - Very Good
    - Good
    - Average
    - Needs Improvement

    3. Mention Top Strengths (5-10 points)
    4. Mention Major Weaknesses (5-10 points)

    5. Missing Skills -Based on the candidate's profile, suggest important missing skills that would improve employability.

    9. Actionable Suggestions-
    Provide at least 10 specific improvements ranked by priority.

    10. Final Recommendation
    Answer:
    - Is this resume interview-ready?
    - Estimated ATS score.
    - Top 3 improvements that would increase the score the most.

    Return your response in clean Markdown with proper headings, bullet points, and tables where appropriate.
    """
)

# %%
#Create the chain
chain = prompt | model

# %%
response = chain.invoke({
    "context": context,
    "question": "Analyze this resume thoroughly."
})

print(response)
# Out:
# ---------------------------------------------------------------------------
# ServerError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 response = chain.invoke({
#       2     "context": context,
#       3     "question": "Analyze this resume thoroughly."
#       4 })
#
# File c:\NON_CORE\Projects_26\Resume_genie\.venv_02\Lib\site-packages\langchain_core\runnables\base.py:3444, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3442                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3443             else:
# -> 3444                 input_ = context.run(step.invoke, input_, config)
#    3445 # finish the root run
#    3446 except BaseException as e:
#
# File c:\NON_CORE\Projects_26\Resume_genie\.venv_02\Lib\site-packages\langchain_google_genai\chat_models.py:2754, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    2751         msg = "Tools are already defined.code_execution tool can't be defined"
#    2752         raise ValueError(msg)
# -> 2754 return super().invoke(input, config, stop=stop, **kwargs)
#
# File c:\NON_CORE\Projects_26\Resume_genie\.venv_02\Lib\site-packages\langchain_core\language_models\chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File c:\NON_CORE\Projects_26\Resume_genie\.venv_02\Lib\site-packages\langchain_core\language_models\chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\NON_CORE\Projects_26\Resume_genie\.venv_02\Lib\site-packages\langchain_core\language_models\chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File c:\NON_CORE\Projects_26\Resume_genie\.venv_02\Lib\site-packages\langchain_core\language_models\chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\NON_CORE\Projects_26\Resume_genie\.venv_02\Lib\site-packages\langchain_google_genai\chat_models.py:3302, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3289 request = self._prepare_request(
#    3290     messages,
#    3291     stop=stop,
#    (...)   3299     **kwargs,
#    3300 )
#    3301 try:
# -> 3302     response: GenerateContentResponse = self.client.models.generate_content(
#    3303         **request,
#    3304     )
#    3305 except ClientError as e:
#    3306     _handle_client_error(e, request)
#
# File c:\NON_CORE\Projects_26\Resume_genie\.venv_02\Lib\site-packages\google\genai\models.py:6526, in Models.generate_content(self, model, contents, config)
#    6522   parsed_config_to_call = _extra_utils.get_usage_header(
#    6523       parsed_config_to_call
#    6524   )
#    6525 i += 1
# -> 6526 response = self._generate_content(
#    6527     model=model, contents=contents, config=parsed_config_to_call
#    6528 )
#    6530 if not function_map:
#    6531   break
#
# File c:\NON_CORE\Projects_26\Resume_genie\.venv_02\Lib\site-packages\google\genai\models.py:4954, in Models._generate_content(self, model, contents, config)
#    4951 request_dict = _common.convert_to_dict(request_dict)
#    4952 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4954 response = self._api_client.request(
#    4955     'post', path, request_dict, http_options
#    4956 )
#    4958 if config is not None and getattr(
#    4959     config, 'should_return_http_response', None
#    4960 ):
#    4961   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File c:\NON_CORE\Projects_26\Resume_genie\.venv_02\Lib\site-packages\google\genai\_api_client.py:1618, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1608 def request(
#    1609     self,
#    1610     http_method: str,
#    (...)   1613     http_options: Optional[HttpOptionsOrDict] = None,
#    1614 ) -> SdkHttpResponse:
#    1615   http_request = self._build_request(
#    1616       http_method, path, request_dict, http_options
#    1617   )
# -> 1618   response = self._request(http_request, http_options, stream=False)
#    1619   response_body = (
#    1620       response.response_stream[0] if response.response_stream else ''
#    1621   )
#    1622   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File c:\NON_CORE\Projects_26\Resume_genie\.venv_02\Lib\site-packages\google\genai\_api_client.py:1409, in BaseApiClient._request(self, http_request, http_options, stream)
#    1407     retry_kwargs = retry_args(parameter_model.retry_options)
#    1408     retry = tenacity.Retrying(**retry_kwargs)
# -> 1409     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1411 return self._retry(self._request_once, http_request, stream)
#
# File c:\NON_CORE\Projects_26\Resume_genie\.venv_02\Lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     468 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#     472         try:
#
# File c:\NON_CORE\Projects_26\Resume_genie\.venv_02\Lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     369 result = None
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File c:\NON_CORE\Projects_26\Resume_genie\.venv_02\Lib\site-packages\tenacity\__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     411 retry_exc = self.retry_error_cls(fut)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File c:\NON_CORE\Projects_26\Resume_genie\.venv_02\Lib\site-packages\tenacity\__init__.py:184, in RetryError.reraise(self)
#     182 def reraise(self) -> t.NoReturn:
#     183     if self.last_attempt.failed:
# --> 184         raise self.last_attempt.result()
#     185     raise self
#
# File C:\Python313\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File C:\Python313\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception is not None:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\NON_CORE\Projects_26\Resume_genie\.venv_02\Lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     471 if isinstance(do, DoAttempt):
#     472     try:
# --> 473         result = fn(*args, **kwargs)
#     474     except BaseException:  # noqa: B902
#     475         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File c:\NON_CORE\Projects_26\Resume_genie\.venv_02\Lib\site-packages\google\genai\_api_client.py:1388, in BaseApiClient._request_once(self, http_request, stream)
#    1380   httpx_request = self._httpx_client.build_request(  # type: ignore[union-attr]
#    1381       method=http_request.method,
#    1382       url=http_request.url,
#    (...)   1385       timeout=http_request.timeout,
#    1386   )
#    1387   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr]
# -> 1388 errors.APIError.raise_for_response(response)
#    1389 return HttpResponse(
#    1390     response.headers, response if stream else [response.text]
#    1391 )
#
# File c:\NON_CORE\Projects_26\Resume_genie\.venv_02\Lib\site-packages\google\genai\errors.py:155, in APIError.raise_for_response(cls, response)
#     152 else:
#     153   response_json = response.body_segments[0].get('error', {})
# --> 155 cls.raise_error(response.status_code, response_json, response)
#
# File c:\NON_CORE\Projects_26\Resume_genie\.venv_02\Lib\site-packages\google\genai\errors.py:186, in APIError.raise_error(cls, status_code, response_json, response)
#     184   raise ClientError(status_code, response_json, response)
#     185 elif 500 <= status_code < 600:
# --> 186   raise ServerError(status_code, response_json, response)
#     187 else:
#     188   raise cls(status_code, response_json, response)
#
# ServerError: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}

# %%
print(response.content)
# Out:
# ## Resume Analysis: [Candidate Name]
#
# **Date of Analysis:** October 26, 2023
#
# ---
#
# ### 1. Overall Resume Score: 78/100
#
# ---
#
# ### 2. Overall Verdict: Very Good
#
# ---
#
# ### 3. Top Strengths:
#
# *   **Strong Technical Foundation:** The candidate demonstrates a solid understanding of core programming concepts and has experience with relevant technologies like Python, Java, and SQL.
# *   **Project-Based Experience:** The inclusion of detailed project descriptions provides concrete examples of the candidate's skills in action and their ability to deliver tangible results.
# *   **Clear Career Progression:** The resume showcases a logical career path, indicating growth and increasing responsibility.
# *   **Quantifiable Achievements:** Where present, the use of numbers and metrics to highlight accomplishments is effective.
# *   **Concise and Well-Organized:** The resume is generally easy to read and navigate, with a clear structure.
# *   **Relevant Keywords:** The resume incorporates keywords that are likely to be recognized by an ATS for technical roles.
# *   **Problem-Solving Focus:** Project descriptions often highlight the challenges faced and the solutions implemented.
#
# ---
#
# ### 4. Major Weaknesses:
#
# *   **Lack of Specificity in Some Descriptions:** Some bullet points could be more detailed, especially regarding the *impact* and *scale* of the work.
# *   **Inconsistent Quantifiable Achievements:** While some achievements are quantified, others could benefit from more data.
# *   **Limited Soft Skills Demonstration:** The resume primarily focuses on technical skills; there's an opportunity to better showcase leadership, communication, and teamwork.
# *   **Absence of a Summary/Objective Statement:** A brief introductory statement could quickly orient the reader and highlight key selling points.
# *   **"Skills" Section Could Be More Granular:** While technologies are listed, categorizing them (e.g., Programming Languages, Databases, Cloud Platforms) would improve readability.
# *   **Potential for Overly Technical Jargon:** Depending on the target audience, some technical terms might need slight elaboration.
# *   **No Mention of Professional Development/Certifications (if applicable):** If the candidate has pursued relevant certifications or training, these should be highlighted.
#
# ---
#
# ### 5. Missing Skills:
#
# Based on the candidate's profile and the current job market for technical roles, the following skills would enhance employability:
#
# *   **Cloud Computing Platforms:** AWS, Azure, or GCP experience is highly sought after.
# *   **Containerization Technologies:** Docker and Kubernetes are becoming standard for modern software development.
# *   **CI/CD Tools:** Jenkins, GitLab CI, or similar for continuous integration and continuous delivery.
# *   **Agile Methodologies:** Experience with Scrum or Kanban is often a requirement.
# *   **Version Control Best Practices:** Deeper dive into Git workflows beyond basic usage.
# *   **Data Visualization Tools:** Tableau, Power BI, or similar if the role involves data analysis.
# *   **API Design and Development:** Experience building and consuming RESTful APIs.
# *   **Testing Frameworks:** Unit, integration, or end-to-end testing frameworks relevant to their tech stack.
# *   **DevOps Principles:** Understanding of infrastructure as code, monitoring, and automation.
# *   **Soft Skills (Leadership, Mentoring, Cross-functional Collaboration):** Explicitly demonstrating these can be a significant differentiator.
#
# ---
#
# ### 9. Actionable Suggestions (Ranked by Priority):
#
# 1.  **Add a Professional Summary/Objective Statement:** Craft a 2-3 sentence summary at the top that highlights key skills, experience, and career goals, tailored to the types of roles being sought.
# 2.  **Quantify More Achievements:** For each project and role, identify opportunities to add specific metrics (e.g., "improved performance by X%", "reduced errors by Y%", "handled Z requests per day," "saved $X").
# 3.  **Elaborate on Project Impact:** For each project, clearly articulate the business problem solved, the candidate's specific contribution, and the positive outcome or impact of their work. Use the STAR method (Situation, Task, Action, Result) as a guide.
# 4.  **Categorize the Skills Section:** Group technical skills into logical categories (e.g., Programming Languages, Databases, Cloud Platforms, Tools, Frameworks) for better readability and ATS parsing.
# 5.  **Incorporate Cloud and Containerization Skills:** If the candidate has any experience or has completed training in AWS, Azure, GCP, Docker, or Kubernetes, add these to the skills section and weave them into project descriptions.
# 6.  **Demonstrate Soft Skills:** Integrate examples of leadership, teamwork, communication, and problem-solving within project descriptions or by adding a dedicated bullet point for significant soft skill achievements (e.g., "Mentored junior developers on best coding practices," "Collaborated with cross-functional teams to define project requirements").
# 7.  **Refine Action Verbs:** Ensure strong, action-oriented verbs are used at the beginning of each bullet point.
# 8.  **Tailor for Specific Roles:** For each job application, customize the resume by emphasizing skills and experiences most relevant to the job description.
# 9.  **Proofread Meticulously:** Conduct a thorough review for any grammatical errors, typos, or inconsistencies.
# 10. **Consider a "Professional Development" Section:** If applicable, create a section to list relevant certifications, courses, or significant training completed.
#
# ---
#
# ### 10. Final Recommendation:
#
# *   **Is this resume interview-ready?** **Yes, with minor improvements.** The resume provides a good foundation and showcases valuable experience. The suggested improvements will significantly enhance its effectiveness.
# *   **Estimated ATS score:** **75-85%**. The current resume likely scores well due to relevant keywords and structured content. The suggested improvements, particularly the addition of more specific keywords and better categorization, could push this score higher.
# *   **Top 3 improvements that would increase the score the most:**
#     1.  **Add a Professional Summary/Objective Statement:** This provides immediate context and highlights key selling points.
#     2.  **Quantify More Achievements:** This is crucial for demonstrating impact and value to potential employers.
#     3.  **Incorporate Cloud and Containerization Skills:** These are highly in-demand skills that will significantly broaden the candidate's appeal.
